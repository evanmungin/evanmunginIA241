# %% [markdown]
# # Question 1.

# %%
my_name="Evan Mungin"

print(my_name)
# Out:
# Evan Mungin

# %% [markdown]
# # Question 2.

# %%
my_id=99

print(my_id)
# Out:
# 99

# %% [markdown]
# # Question 3.

# %%
my_id_str="99"

print(my_id_str)
# Out:
# 99

# %% [markdown]
# # Question 4.

# %%
my_name+my_id

You cannot perform this due to an error in formats. 
They must both be in str, not int.
# Out:
#   File "<ipython-input-22-bc3d2dc6a1f8>", line 3
#     You cannot perform this due to an error in formats.
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # Question 5

# %%
my_name+my_id_str

#Yes, you can perform this due to both of the values being in string format.
# Out:
# 'Evan Mungin99'

# %% [markdown]
# # Question 6

# %%
my_str="hello, world. This is my first python string."

print(my_str)
# Out:
# hello, world. This is my first python string.

# %%
print(my_str.split("."))
# Out:
# ['hello, world', ' This is my first python string', '']

# %% [markdown]
# # Question 7.

# %%
str_list=["a","b","c","e","d"]

str_list.sort()

print(str_list)

#Yes, you can sort the list due to the correct format.
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# # Question 8

# %%
str_list.append("f")

print(str_list)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# # Question 9

# %%
str_list.remove("d")

print(str_list)
# Out:
# ['a', 'b', 'c', 'e', 'f']

# %% [markdown]
# # Question 10

# %%
print(str_list[2])
# Out:
# c

# %% [markdown]
# # Question 11

# %%
num_list=[12,32,43,35]

print(str_list+num_list)

#Yes, you can add these two together due to both of them being lists.
# Out:
# ['a', 'b', 'c', 'e', 'f', 12, 32, 43, 35]

# %% [markdown]
# # Question 12

# %%
my_dict={"name":"Evan","id":(my_id)}

print(my_dict)
# Out:
# {'name': 'Evan', 'id': 99}

# %% [markdown]
# # Question 13

# %%
my_dict["name"]="Mungin"

print(my_dict)
# Out:
# {'name': 'Mungin', 'id': 99}

# %% [markdown]
# # Question 14

# %%
print(my_dict["id"])
# Out:
# 99

# %% [markdown]
# # Question 15

# %%
my_dict["id"]=77

print(my_dict)
# Out:
# {'name': 'Mungin', 'id': 77}

# %% [markdown]
# # Question 16

# %%
my_dict["num_list"]=num_list

print(my_dict)
# Out:
# {'name': 'Mungin', 'id': 77, 'num_list': [12, 32, 43, 35]}

# %% [markdown]
# # Question 17

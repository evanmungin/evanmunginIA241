# %% [markdown]
# # Question 1

# %%
num_list = [12, 32, 43, 35]

print(num_list)
# Out:
# [12, 32, 43, 35]

# %%
num_list.sort()

print(num_list)

print(num_list[0])
print(num_list[-1])
# Out:
# [12, 32, 35, 43]
# 12
# 43

# %% [markdown]
# # Question 2

# %%
my_string="This is my third python lab."

print(my_string)
# Out:
# This is my third python lab.

# %%
my_list=my_string.split()

print(my_list)

len(my_list)
# Out:
# ['This', 'is', 'my', 'third', 'python', 'lab.']
# 6

# %% [markdown]
# # Question 3

# %%
my_list = ("a","123",123,"b","B","False",False,123,None,"None")

my_set_from_list=set(my_list)

print(my_set_from_list)

len(my_set_from_list)

#There are 9 unique items in this list as counted below after utilizing set function.
# Out:
# {False, 'b', 'False', None, 'None', '123', 'a', 'B', 123}
# 9

# %% [markdown]
# # Question 4

# %%
my_dict={"favorite_count":1138,"lang":"ch","coordinates":(-75.14310264,40.05701649),
         "visited_countries":["GR","HK","MY"]}

print(my_dict)
# Out:
# {'favorite_count': 1138, 'lang': 'ch', 'coordinates': (-75.14310264, 40.05701649), 'visited_countries': ['GR', 'HK', 'MY']}

# %% [markdown]
# ##  4.1

# %%
my_dict["lang"]="en"
my_dict.get("lang")
# Out:
# 'en'

# %% [markdown]
# ## 4.2

# %%
len(my_dict["visited_countries"])
# Out:
# 3

# %% [markdown]
# ## 4.3

# %%
my_dict["visited_countries"].append('CH')

print(my_dict)
# Out:
# {'favorite_count': 1138, 'lang': 'en', 'coordinates': (-75.14310264, 40.05701649), 'visited_countries': ['GR', 'HK', 'MY', 'CH']}

# %% [markdown]
# ## 4.4

# %%
print("US" in my_dict)
# Out:
# False

# %% [markdown]
# ## 4.5

# %%
print(my_dict["coordinates"][0])
# Out:
# -75.14310264

# %% [markdown]
# ## 4.6

# %%
my_dict["coordinates"]=(-81,45)
my_dict.get("coordinates")
# Out:
# (-81, 45)

# %%
print(my_dict)
# Out:
# {'favorite_count': 1138, 'lang': 'en', 'coordinates': (-81, 45), 'visited_countries': ['GR', 'HK', 'MY', 'CH']}

# %%
#Yes, you can.
